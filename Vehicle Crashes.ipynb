# 2  2018005742         6      23         23111       23111        2018
# 3  2018005777         5      48         48301       48501        2018
# 4  2018003363         9       7          7201       68G01        2018
#
#    CRASH_MONTH  DAY_OF_WEEK TIME_OF_DAY HOUR_OF_DAY  ...  PED_DEATH_COUNT  \
# 0            1            3        0810          08  ...                0
# 1            1            2        1624          16  ...                0
# 2            1            5        2055          20  ...                0
# 3            1            6        0500          05  ...                0
# 4            1            3        0118          01  ...                0
#
#   PED_MAJ_INJ_COUNT  MAX_SEVERITY_LEVEL  COMM_VEH_COUNT  DEC_LAT DEC_LONG  \
# ...

# %%
crashes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128411 entries, 0 to 128410
# Data columns (total 91 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   CRN                    128411 non-null  int64
#  1   DISTRICT               128411 non-null  int64
#  2   COUNTY                 128411 non-null  int64
#  3   MUNICIPALITY           128411 non-null  int64
#  4   POLICE_AGCY            128411 non-null  object
#  5   CRASH_YEAR             128411 non-null  int64
#  6   CRASH_MONTH            128411 non-null  int64
#  7   DAY_OF_WEEK            128411 non-null  int64
#  8   TIME_OF_DAY            128411 non-null  object
#  9   HOUR_OF_DAY            128411 non-null  object
#  10  ILLUMINATION           128411 non-null  int64
#  11  WEATHER                128411 non-null  object
#  12  ROAD_CONDITION         128410 non-null  float64
#  13  COLLISION_TYPE         128411 non-null  int64
# ...

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# The first step in cleaning the data will be to simply make the column names lowercase. This will improve readability and also make writing this code a bit easier.

# %%
crashes.columns = map(str.lower, crashes.columns)
crashes = crashes.rename(columns={'crn':'crash_number', 'crash_year': 'year', 'crash_month': 'month'})

# %% [markdown]
# The next step will be to fill any blank values with NaN and create a heatmap to determine what areas of the dataset have missing values.

# %%
crashes = crashes.replace(r'^\s*$', np.nan, regex=True)

# %%
#Import seaborn to utilize the heatmap function
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

#Create function to print a heatmap of null values in the dataset
def null_plot(df, figsize=(18,15)):
    plt.figure(figsize=figsize)
    df_null = df.isnull()
    sns.heatmap(~df_null, cbar=False, yticklabels=False)
    plt.xticks(rotation=90, size='x-large')
    plt.show()
    
null_plot(crashes)

# %% [markdown]
# Luckily, the "dirtier" parts of this dataset are ones that are not of great interest for this analysis. We can see that there are many columns that are almost entirely null. Many of these are related to crashes that occur in work/construction zones. Because this is such a large amount of the data set and we are not specifically concerned with work zone related crashes, I will just drop these columns from the dataset.

# %%
#Remove columns related to work zone crashes
drop_columns = ['work_zone_type', 'work_zone_loc', 'cons_zone_spd_lim', 'workers_pres',
                'wz_close_detour', 'wz_flagger', 'wz_law_offcr_ind', 'wz_ln_closure',
                'wz_moving', 'wz_other', 'wz_shlder_mdn', 'rdwy_surf_type_cd', 'spec_juris_cd', 
                'est_hrs_closed', 'ln_close_dir', 'tfc_detour_ind']

crashes = crashes.drop(columns=drop_columns)

# %%
null_plot(crashes)

# %% [markdown]
# # Heatmap of Crash Locations
#
# Utilizing the Basemap package, we can create a heatmap to help visualize where crashes occur the most across the state.

# %%
#Import Basemap package 
from mpl_toolkits.basemap import Basemap

#Create a new dataset to remove entries with missing coordinates
coordinates = crashes[(crashes['dec_long'].notnull()) & (crashes['dec_lat'].notnull())][['dec_lat', 'dec_long']]

# %%
def heatmap(lats, lons, title, scale=5, cmap="hot_r", gridsize=75, mincnt=1):
    #Using the min and max longitudes and latitudes to determine borders for map
    llcrnrlat = lats.min() - 0.1
    urcrnrlat = lats.max() + 0.1
    llcrnrlon = lons.min() - 0.1
    urcrnrlon = lons.max() + 0.1

    #Create a figure to display the entire state of Pennsylvania
    fig = plt.figure(num=None, 
                     figsize=(
                              scale*(abs(urcrnrlat - llcrnrlat)), 
                              scale*(abs(llcrnrlon - urcrnrlon))
                     )
                    )
                    
    m = Basemap(llcrnrlat=llcrnrlat, urcrnrlat=urcrnrlat, llcrnrlon=llcrnrlon, urcrnrlon=urcrnrlon, resolution='h')

    #Define coordinates from the dataset
    x_plot = np.array(lons)
    y_plot = np.array(lats)

    #Create a hexbin overlay of the coordinates to show areas of higher frequency
    m.hexbin(x_plot, y_plot, mincnt=mincnt, gridsize=gridsize, cmap=cmap)

    m.colorbar(location='bottom', label='Number of Crashes')

    #Draw borders for counties, states, and coasts
    m.drawstates(linewidth=0.5, linestyle='solid', color='black')
    m.drawcounties(linewidth=0.5, linestyle='solid', color='grey')
    m.drawcoastlines(linewidth=0.5, linestyle='solid', color='black')
    
    plt.title(title)
    
heatmap(coordinates['dec_lat'], 
        coordinates['dec_long'], 
        "Pennsylvania Road Crashes, 2018"
       )

#Create a dictionary of large Pennsylvania cities and their coordinates
cities = {'Pittsburgh':(40.444, -79.997), 'Philadelphia':(39.946, -75.152),
          'Allentown':(40.600, -75.471), 'Reading':(40.334, -75.927),
          'Harrisburg':(40.253, -76.865), 'Erie':(42.128, -80.086), 
          'York':(39.963, -76.730), 'Lancaster':(40.039, -76.312), 
          'Scranton':(41.407, -75.663), 'Wilkes-Barre':(41.245, -75.872)}
          
#Plot and label the cities in the map
for key in cities:
    plt.text(cities[key][1]+.03, cities[key][0]+.03, '{}'.format(key), fontweight='bold', color='k')

plt.show()

# %% [markdown]
# Let's look closer at Philadelphia so that we can get a better image of the distribution of crashes in that area.

# %%
philly_crashes = crashes[(crashes["dec_long"].notnull()) & 
                         (crashes["dec_lat"].notnull()) & 
                         (crashes["county_name"] == "Philadelphia")][["dec_lat", "dec_long"]]

heatmap(philly_crashes["dec_lat"], 
        philly_crashes["dec_long"], 
        "Philadelphia Road Crashes, 2018", 
        scale=10, 
        gridsize=30 
        )

plt.show()

# %% [markdown]
# This map shows that there are more crashes around the highways leading into and out of the city and a concentration in the city itself.

# %% [markdown]
# ### Crash Frequency by County

# %%
county_freq = crashes['county_name'].value_counts()

county_freq.head(10).plot(kind="bar")

# %% [markdown]
# This chart shows that the Pittsburgh area had the most crashes in the state in 2018. This is likely due in part to the size of Allegheny county; Philadelphia and Montgomery counties appear to cover a similar area as Allegheny.

# %%
muni_freq = crashes["municipality_name"].value_counts()

muni_freq.head(10).plot(kind="bar")

# %% [markdown]
# Despite Allegheny county having the most crashes, we can see that Philadelphia city has far and away the most crashes in the state.

# %% [markdown]
# ### Crashes by Month

# %%
crash_by_month = crashes['month'].value_counts().sort_index()
crash_by_month = pd.DataFrame(crash_by_month)
crash_by_month.reset_index(level=0, inplace=True)
crash_by_month.rename(columns={'index':'month', 'month':'count'}, inplace=True)
crash_by_month
# Out:
#     month  count
# 0       1  12500
# 1       2  10740
# 2       3  10457
# 3       4   8727
# 4       5  10478
# 5       6   9921
# 6       7  10026
# 7       8  10302
# 8       9  10225
# 9      10  11776
# 10     11  12369
# 11     12  10890

# %%
#Import datetime package to convert numerical dates 
import datetime as dt

#Create a function to convert from integers to month names
def month_name(month):
    datetime_object = dt.datetime.strptime(str(month), '%m')
    month_name = datetime_object.strftime('%B')
    return month_name

#Apply the previously created formula to the month column to create 'month_name'
crash_by_month['month_name'] = crash_by_month['month'].apply(month_name)

crash_by_month['percentage'] = (crash_by_month['count'] / crash_by_month['count'].sum())

crash_by_month
# Out:
#     month  count month_name  percentage
# 0       1  12500    January    0.097344
# 1       2  10740   February    0.083638
# 2       3  10457      March    0.081434
# 3       4   8727      April    0.067961
# 4       5  10478        May    0.081597
# 5       6   9921       June    0.077260
# 6       7  10026       July    0.078077
# 7       8  10302     August    0.080227
# 8       9  10225  September    0.079627
# 9      10  11776    October    0.091706
# 10     11  12369   November    0.096324
# 11     12  10890   December    0.084806

# %%
#Create a bar chart containing frequencies
fig1 = plt.figure(num=1, figsize=(5,5))
crash_by_month.plot(kind="bar", x='month_name', y='count', legend=False)
plt.axhline(crash_by_month['count'].mean(), color='orange', label = "mean")
plt.xlabel('Month')
plt.ylabel('Crashes')
plt.title('Pennsylvania Motor Vehicle Crashes by Month, 2018')

print("Percentage of annual crashes in above average months: " + 
      round(crash_by_month[crash_by_month['count'] > crash_by_month['count'].mean()]['percentage'].sum()*100,2).astype(str).format() + "%")
# Out:
# Percentage of annual crashes in above average months: 45.38%

# %% [markdown]
# This bar chart shows that, as one would expect, vehicles crashes occur at an above average rate during the winter months (October - February), with 45% of the total crashes for the year occurring in these five months.

# %% [markdown]
# ## Fatal Car Crashes

# %%
fatal_crashes = crashes[crashes["fatal_count"] > 0]

fatalities_by_county = pd.DataFrame(fatal_crashes["county_name"].value_counts())

fatalities_by_county.columns = ["fatalities"]

fig, ax = plt.subplots()
ax.pie(fatalities_by_county["fatalities"].head(10), labels=fatalities_by_county.head(10).index, autopct='%1.1f%%')
ax.set_title("Fatalities by County (Ten Highest Fatality Counts)")

plt.show()
